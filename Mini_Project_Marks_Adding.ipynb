# %% [markdown]
# <a href="https://colab.research.google.com/github/HarjotSingh-b18055/Mini-Project-Marks-Adding/blob/main/Mini_Project_Marks_Adding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('/content/Mini Project - Marks Adding.csv')
df
# Out:
#        Roll Num  Marks
# 0     102003542      1
# 1     102003640      1
# 2     102003725      1
# 3     102003307      1
# 4     102003458      1
# ...         ...    ...
# 1831  102003755      1
# 1832  102017147      1
# 1833  102017152      1
# 1834  102003451      1
# 1835  102003549      1
#
# [1836 rows x 2 columns]

# %%
added_marks = df.groupby('Roll Num')['Marks'].sum().reset_index()
added_marks
# Out:
#       Roll Num  Marks
# 0    102003001      3
# 1    102003002      5
# 2    102003017      5
# 3    102003018      5
# 4    102003029      5
# ..         ...    ...
# 395  102196010      4
# 396  102197016      5
# 397  102197018      4
# 398  102197019      5
# 399  102197021      5
#
# [400 rows x 2 columns]

# %%
added_marks.to_csv('./added_marks.csv', index=False)
